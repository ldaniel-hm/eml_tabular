# %% [markdown]
# # Práctica RL - Parte 3
#
# Ejecución completa en Colab con semilla fija `SEED=2024`.

# %%
# Si se ejecuta en Colab, descomentar:
# !git clone https://github.com/fraycarmona/eml_tabular_grupo_17.git
# %cd eml_tabular_grupo_17/src/EntornosComplejos
# !pip install -r requirements.txt

SEED = 2024
import random
import numpy as np
import torch

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
print('Semilla fijada:', SEED)

# %%
# %run estudiosarsa.ipynb

# %%
# %run estudiodqn.ipynb
